# %%
# import library
import requests, xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
gs = pd.read_csv('./세종특별자치시_주유소현황_20211013.csv', encoding='euc-kr')

# %%
gs
# Out:
#          지역                    상호                     주소      상표  \
# 0   세종특별자치시             세종동부농협주유소   세종특별자치시 부강면 부강외천로 10  NH-OIL
# 1   세종특별자치시   ㈜선인상사 우리나라주유소(명칭변경)  세종특별자치시 전의면 운주산로 1032   S-OIL
# 2   세종특별자치시                굿모닝주유소  세종특별자치시 조치원읍 세종로 2712    자가상표
# 3   세종특별자치시                 신안주유소  세종특별자치시 조치원읍 세종로 2678    자가상표
# 4   세종특별자치시                 진영주유소  세종특별자치시  소정면 세종로 4732  현대오일뱅크
# ..      ...                   ...                    ...     ...
# 65  세종특별자치시                 범한주유소   세종특별자치시 소정면 세종로 4679   S-OIL
# 66  세종특별자치시       SK세종전의주유소(명칭변경)   세종특별자치시 전의면 세종로 3907    자가상표
# 67  세종특별자치시              서세종농협주유소    세종특별자치시 연서면 함박로 122   SK에너지
# 68  세종특별자치시  SK엔크린 세종대평주유소(신규 추가)      세종특별자치시 종합운동장로 29   SK에너지
# 69  세종특별자치시      세종중앙농협주유소(신규 추가)      세종특별자치시 연기면 잣띠길 4    자가상표
#
#              전화번호 셀프여부         위도          경도
# 0    044-868-6145    Y  36.671429  127.217462
# 1    044-868-2051    N  36.627999  127.289747
# ...

# %%
gs = gs.drop(['지역','상표','전화번호','셀프여부'], axis=1)

# %%
gs
# Out:
#                       상호                     주소         위도          경도
# 0              세종동부농협주유소   세종특별자치시 부강면 부강외천로 10  36.671429  127.217462
# 1    ㈜선인상사 우리나라주유소(명칭변경)  세종특별자치시 전의면 운주산로 1032  36.627999  127.289747
# 2                 굿모닝주유소  세종특별자치시 조치원읍 세종로 2712  36.625103  127.290555
# 3                  신안주유소  세종특별자치시 조치원읍 세종로 2678  36.731322  127.168313
# 4                  진영주유소  세종특별자치시  소정면 세종로 4732  36.559414  127.281363
# ..                   ...                    ...        ...         ...
# 65                 범한주유소   세종특별자치시 소정면 세종로 4679  36.728124  127.163772
# 66       SK세종전의주유소(명칭변경)   세종특별자치시 전의면 세종로 3907  36.678892  127.184938
# 67              서세종농협주유소    세종특별자치시 연서면 함박로 122  36.575753  127.264680
# 68  SK엔크린 세종대평주유소(신규 추가)      세종특별자치시 종합운동장로 29  36.469020  127.268350
# 69      세종중앙농협주유소(신규 추가)      세종특별자치시 연기면 잣띠길 4  36.548830  127.278800
#
# [70 rows x 4 columns]

# %%
gs.to_csv('세종_주유소_현황.csv',index=False,encoding='euc-kr')
